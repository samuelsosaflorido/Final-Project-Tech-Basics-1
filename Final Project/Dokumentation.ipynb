# %% [markdown]
# # Final Coding Project
# ___
# ##### *by Samuel Sosa Florido, Katharina Noske, Karoline Fischer*
# ___
#
# In this dokument we try to clear explain our project's development process and how we evolved from a simple idea to the final product.
#
# - Our idea began with a brainstorming. Doing this brainstorming we decided to make an escape room.
# - After we had the rough idea, we decided on the setting: a prison
# - We decided on the rough game style (our mini games to escape, everyone is doinig a own room and that we want to use a maze in between the rooms)
# - we written down or idea: https://1drv.ms/b/c/d455f6e8aefaf6c5/IQDB6_R5QBU7QbN5NmStvxhqAQtefoIJEWgFYN1m-DJsd9g?e=yylPnJ
# - Further we began with the set up for the final presentation:
# 1. we sketched the backgrounds of the rooms
# 2. we started with the first version of the maze
# 3. we did the first plan how to code the game (in witch order and what sources we need)
#
# our presentation: https://canva.link/u7sdp2u62pfdv1x
#
# ___
# ##### Samuel:
# add some basic information about your coding experience here
#
# ##### Kathi:
# I mainly followed different tutorials online. For example, I used this video https://www.youtube.com/watch?v=AY9MnQ4x3zk and this playlist https://www.youtube.com/@lemastertech/playlists to get an overview.
# When I had troubles with the code I asked my boyfriend insted of AI for help, because my he is an app developer.
# He did sit down with me and asked me what the issu is, what I would like to do and how I plan to do it. If I had troubles to find my issu he showed and explained it to me. Because of that I understood the problems and if needed we figued out how to fix it toghether.
# (If I did use AI anyway or in addition,it is of course marked)
#
# ##### Karo:
# add some basic information about your coding experience here
#
# #### more information about the process and our problems is in each phyton file at the beginning (there you can also find who coded which part)
